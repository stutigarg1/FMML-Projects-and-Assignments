# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 15:53:43--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  77.4MB/s    in 0.9s
#
# 2025-03-16 15:53:46 (77.4 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10129  1707.06354v2  As intelligent systems gain autonomy and capab...    cs
# 6063   1606.07129v1  Most accurate recommender systems are black-bo...  stat
# 7542   1802.02798v1  Transductive Adversarial Networks (TAN) is a n...  stat
# 38730   1010.0301v1  An inverse iterative algorithm for microwave i...    cs
# 574    1504.01106v5  This paper proposes a tree-based convolutional...    cs
# ...             ...                                                ...   ...
# 39371  1601.02970v1  The complex multi-stage architecture of cortic...    cs
# 32845  1509.01659v1  The downfall of many supervised learning algor...    cs
# 30472  1712.02933v1  We propose to learn a fully-convolutional netw...    cs
# 6260   1610.06434v1  The ability of a human being to extrapolate pr...  stat
# 16308  1611.09020v2  Cardiovascular disease (CVD) has become the le...    cs
#
#                                                    title  year  \
# 10129                Pragmatic-Pedagogic Value Alignment  2017
# 6063   Explainable Restricted Boltzmann Machines for ...  2016
# 7542             Transductive Adversarial Networks (TAN)  2018
# 38730  A Microwave Imaging and Enhancement Technique ...  2010
# 574    Discriminative Neural Sentence Modeling by Tre...  2015
# ...                                                  ...   ...
# 39371  Deep Neural Networks predict Hierarchical Spat...  2016
# 32845                           Gravitational Clustering  2015
# 30472  Chaining Identity Mapping Modules for Image De...  2017
# 6260   Kernel Alignment for Unsupervised Transfer Lea...  2016
# 16308  Developing a cardiovascular disease risk facto...  2016
#
#                                                 keywords
# 10129  [intelligent, capability, objectives, alignmen...
# 6063   [recommender, reasoning, recommendations, expl...
# 7542   [transductive, adversarial, adaptation, framew...
# 38730  [iterative, algorithm, microwave, presented, i...
# 574    [convolutional, discriminative, constituency, ...
# ...                                                  ...
# 39371  [architecture, efficient, recognition, computa...
# 32845  [supervised, algorithms, classification, inher...
# 30472  [convolutional, denoising, structure, possesse...
# 6260   [extrapolate, previously, knowledge, assumptio...
# 16308  [cardiovascular, prevented, controlling, annot...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10129    [intelligent, capability, objectives, alignmen...
# 6063     [recommender, reasoning, recommendations, expl...
# 7542     [transductive, adversarial, adaptation, framew...
# 38730    [iterative, algorithm, microwave, presented, i...
# 574      [convolutional, discriminative, constituency, ...
#                                ...
# 15796    [introduce, available, syntactic, annotated, u...
# 31720    [distributions, minimizing, distribution, algo...
# 22647    [available, potentially, challenge, algorithms...
# 15451    [improving, statistical, translation, applicat...
# 22041    [considers, estimating, structure, development...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8870 words.
# Out of those 4588 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="144568b4-32a9-49e8-a335-7b28793c5dee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("144568b4-32a9-49e8-a335-7b28793c5dee")) {                    Plotly.newPlot(                        "144568b4-32a9-49e8-a335-7b28793c5dee",                        [{"x":["integrate","meaningful","pragmatic","reciprocity","alignment","workflows","knowledge","constitutes","empirically","intelligent","capability","objectives","mathematical","successfully","cognitive","capabilities","interpret","reinforcement","inferring","cognition","established","isolation","cooperative","validated","anticipate","collaborative","technique","generating","explanations","automated","recommendations","explanation","generated","boltzmann","explainable","reasoning","restricted","attributes","generation","providing","transparency","recommender","additional","interpretability","experimental","filtering","recommendation","effective","leverages","generalised","accurately","combination","adversarial","available","demonstrates","procedure","viability","different","transductive","distribution","architecture","approximates","framework","probability","theoretical","adaptation","unlabelled","marginalised","approximate","algorithm","distributions","algorithms","potential","conditional","presented","developed","constrained","iterative","microwave","contaminated","marquardt","reconstructed","optimization","percentage","enhancement","posedness","synthetic","outperforms","dependency","experiments","dedicated","underlying","propagation","engineering","including","detectors","classification","sentiment","structural","constituency","convolution","convolutional","sentences","discriminative","visualize","extraction","aggregated","corresponds","replacement","justification","looseness","relaxation","prediction","beneficial","parameter","regularization","complexity","demonstrating","particular","generalization","landscape","empirical","clustering","automatically","predictive","information","methodologies","regression","structure","performance","interesting","assumption","simultaneously","discovered","applications","demonstrate","hierarchical","usefulness","groupings","perspective","phenotypes","discovering","variables","varieties","hierarchy","multitask","parameters","individual","correlation","operation","calculating","incorporating","calculate","outperforming","processing","similarity","coefficient","benchmark","standards","statistics","methodology","analytics","advantage","supervised","incorporate","community","initially","functions","effectiveness","unlabeled","detection","evidential","identified","propagate","expressed","computation","convergence","truncation","efficiently","conditioned","programming","precision","component","efficient","formulation","inference","concerning","computational","excellent","compromise","potentials","lagrangian","conjugate","construction","gradients","convergent","investigate","relaxations","substantial","carefully"],"y":[46,49,11,1,55,7,360,8,73,50,54,28,55,84,51,41,19,117,27,16,58,7,14,26,9,38,250,97,15,113,18,16,171,14,3,113,47,62,121,89,4,18,128,12,393,66,33,227,32,3,69,128,97,324,52,112,5,741,5,219,246,10,543,174,159,57,4,0,111,790,106,603,160,87,203,190,64,69,2,5,2,32,311,8,23,1,129,262,44,618,21,113,84,50,255,35,511,52,80,4,49,386,71,104,19,142,14,21,6,10,0,21,216,22,126,87,235,27,265,122,10,160,142,182,51,733,25,116,339,910,65,60,124,28,458,543,99,24,1,61,0,25,111,0,33,5,252,120,79,36,24,65,26,27,306,167,30,203,7,62,76,12,86,191,67,75,22,212,223,42,332,8,34,8,45,142,116,3,159,18,118,72,112,390,104,207,18,287,31,6,16,10,11,57,36,7,155,5,38,27],"type":"bar"},{"x":["integrate","meaningful","pragmatic","reciprocity","alignment","workflows","kno ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4588,), (4588, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Marking</span> <span style=''>up</span> <span style=''>multiple</span> <span style=''>views</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Text</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Discourse</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Reference</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>an</span> <span style=''>encoding</span> <span style=''>scheme</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discourse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>reference</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>TEI</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923077);'>Guidelines</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Corpus</span> <span style=''>Encoding</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Specification</span> <span style=''>(CES)</span> <span style=''>A</span> <span style=''>central</span> <span style=''>feature</span> <span style=''>of</span> <span style=''>the</span> <span style=''>scheme</span> <span style=''>is</span> <span style=''>a</span> <span style=''>CES</span> <span style=''>based</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.5569620253164556);'>architecture</span> <span style=''>enabling</span> <span style=''>the</span> <span style=''>encoding</span> <span style=''>of</span> <span style=''>and</span> <span style=''>access</span> <span style=''>to</span> <span style=''>multiple</span> <span style=''>views</span> <span style=''>of</span> <span style=''>a</span> <span style=''>marked</span> <span style=''>up</span> <span style=''>document</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>tool</span> <span style='background-color:rgba(0, 255, 0, 0.5569620253164556);'>architecture</span> <span style=''>that</span> <span style=''>supports</span> <span style=''>the</span> <span style=''>encoding</span> <span style=''>scheme</span> <span style=''>and</span> <span style=''>then</span> <span style=''>show</span> <span style=''>how</span> <span style=''>we</span> <span style=''>have</span> <span style=''>used</span> <span style=''>the</span> <span style=''>encoding</span> <span style=''>scheme</span> <span style=''>and</span> <span style=''>the</span> <span style=''>tools</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discourse</span> <span style=''>analytic</span> <span style=''>task</span> <span style=''>in</span> <span style=''>support</span> <span style=''>of</span> <span style=''>a</span> <span style=''>model</span> <span style=''>of</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discourse</span> <span style=''>cohesion</span> <span style=''>called</span> <span style=''>Veins</span> <span style=''>Theory</span> <span style=''>(Cristea</span> <span style=''>Ide</span> <span style=''>1998)</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Accuracy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reliability</span> <span style=''>Cost</span> <span style=''>Function</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assigning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainties</span> <span style=''>to</span> <span style=''>single</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>that</span> <span style=''>encodes</span> <span style=''>the</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>between</span> <span style=''>accuracy</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reliability</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>forecast</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>analytic</span> <span style=''>formula</span> <span style=''>for</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>scalar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>The</span> <span style=''>Accuracy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reliability</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heteroskedastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>(input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>noise)</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>philosophy</span> <span style=''>behind</span> <span style=''>this</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variances</span> <span style=''>should</span> <span style=''>be</span> <span style=''>both</span> <span style=''>accurate</span> <span style=''>and</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3573407202216066);'>convergence</span> <span style=''>of</span> <span style=''>Loopy</span> <span style=''>Belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <br/><br/><span style=''>We</span> <span style=''>derive</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3573407202216066);'>convergence</span> <span style=''>of</span> <span style=''>Loopy</span> <span style=''>Belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style=''>(also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Sum</span> <span style=''>Product</span> <span style=''>algorithm)</span> <span style=''>to</span> <span style=''>a</span> <span style=''>unique</span> <span style=''>fixed</span> <span style=''>point</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>improve</span> <span style=''>upon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>For</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.40641711229946526);'>variables</span> <span style=''>with</span> <span style=''>(anti</span> <span style=''>)ferromagnetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>seem</span> <span style=''>to</span> <span style=''>be</span> <span style=''>sharp</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>PAC</span> <span style=''>Bayesian</span> <span style=''>Majority</span> <span style=''>Vote</span> <span style=''>for</span> <span style=''>Late</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifier</span> <span style=''>Fusion</span> <br/><br/><span style=''>A</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>has</span> <span style=''>been</span> <span style=''>devoted</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multimedia</span> <span style=''>indexing</span> <span style=''>over</span> <span style=''>the</span> <span style=''>past</span> <span style=''>few</span> <span style=''>years</span> <span style=''>In</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>we</span> <span style=''>often</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>kinds</span> <span style=''>of</span> <span style=''>fusion</span> <span style=''>schemes</span> <span style=''>The</span> <span style=''>early</span> <span style=''>fusion</span> <span style=''>and</span> <span style=''>the</span> <span style=''>late</span> <span style=''>fusion</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>late</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>fusion</span> <span style=''>where</span> <span style=''>one</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>scores</span> <span style=''>of</span> <span style=''>each</span> <span style=''>modality</span> <span style=''>at</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>level</span> <span style=''>To</span> <span style=''>tackle</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>and</span> <span style=''>elegant</span> <span style=''>well</span> <span style=''>founded</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style=''>program</span> <span style=''>named</span> <span style=''>MinCq</span> <span style=''>coming</span> <span style=''>from</span> <span style=''>the</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>PAC</span> <span style=''>Bayes</span> <span style=''>theory</span> <span style=''>MinCq</span> <span style=''>looks</span> <span style=''>for</span> <span style=''>the</span> <span style=''>weighted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>over</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>real</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>voters</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>the</span> <span style=''>lowest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>misclassification</span> <span style=''>rate</span> <span style=''>while</span> <span style=''>making</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>voters</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diversity</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>evidence</span> <span style=''>that</span> <span style=''>this</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>late</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13390619405657)
# 	segmentation (0.07303974221267455)
# 	experimental (0.14070891514500536)
# 	processing (0.10955961331901182)
# 	knowledge (0.1288936627282492)
# 	detection (0.11886860007160759)
# 	information (0.26244181883279627)
# 	different (0.2653061224489796)
# 	recognition (0.13462226996061583)
# 	convolutional (0.13820264948084496)
#
# Some Statistics words are:
# 	stochastic (0.13153961136023917)
# 	statistical (0.1489785749875436)
# 	variables (0.1310413552566019)
# 	estimation (0.17787742899850523)
# 	theoretical (0.16093672147483806)
# 	distribution (0.1878425510712506)
# 	algorithm (0.4020926756352765)
# 	dimensional (0.18834080717488788)
# 	inference (0.1963129048330842)
# 	regression (0.19133034379671152)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="528d6267-79a0-4626-ae0f-3c92175aeffd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("528d6267-79a0-4626-ae0f-3c92175aeffd")) {                    Plotly.newPlot(                        "528d6267-79a0-4626-ae0f-3c92175aeffd",                        [{"x":["integrate","meaningful","pragmatic","reciprocity","alignment","workflows","knowledge","constitutes","empirically","intelligent","capability","objectives","mathematical","successfully","cognitive","capabilities","interpret","reinforcement","inferring","cognition","established","isolation","cooperative","validated","anticipate","collaborative","technique","generating","explanations","automated","recommendations","explanation","generated","boltzmann","explainable","reasoning","restricted","attributes","generation","providing","transparency","recommender","additional","interpretability","experimental","filtering","recommendation","effective","leverages","generalised","accurately","combination","adversarial","available","demonstrates","procedure","viability","different","transductive","distribution","architecture","approximates","framework","probability","theoretical","adaptation","unlabelled","marginalised","approximate","algorithm","distributions","algorithms","potential","conditional","presented","developed","constrained","iterative","microwave","contaminated","marquardt","reconstructed","optimization","percentage","enhancement","posedness","synthetic","outperforms","dependency","experiments","dedicated","underlying","propagation","engineering","including","detectors","classification","sentiment","structural","constituency","convolution","convolutional","sentences","discriminative","visualize","extraction","aggregated","corresponds","replacement","justification","looseness","relaxation","prediction","beneficial","parameter","regularization","complexity","demonstrating","particular","generalization","landscape","empirical","clustering","automatically","predictive","information","methodologies","regression","structure","performance","interesting","assumption","simultaneously","discovered","applications","demonstrate","hierarchical","usefulness","groupings","perspective","phenotypes","discovering","variables","varieties","hierarchy","multitask","parameters","individual","correlation","operation","calculating","incorporating","calculate","outperforming","processing","similarity","coefficient","benchmark","standards","statistics","methodology","analytics","advantage","supervised","incorporate","community","initially","functions","effectiveness","unlabeled","detection","evidential","identified","propagate","expressed","computation","convergence","truncation","efficiently","conditioned","programming","precision","component","efficient","formulation","inference","concerning","computational","excellent","compromise","potentials","lagrangian","conjugate","construction","gradients","convergent","investigate","relaxations","substantial","carefully","disparate","solutions","influential","identifying","requiring","predictions","maximally","challenges","explaining","determine","prototypes","introduces","approaches","uncovering","specified","classical","effectively","estimator","estimators","transform","shrinkage","autoencoding","equivalent","autoencoder","estimation","bootstrap","isotropic","specifying","estimates","resulting","iterating","variances","reweighted","iteratively","components","generalisations","illustrative","discriminant","principal","represent","compression","recognition","automatic","inductive","introduced","computationally","switchboard","recurrent","examining","generalizes","presumably","difficulty","selection","bivariate","intractable","multivariate","attention"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	marginalised
# 	looseness
# 	phenotypes
# 	varieties
# 	statisticians
# 	compresses
# 	diffraction
# 	unchanged
# 	subsample
# 	inhibited
# 	compounded
# 	deterioration
# 	crossings
# 	advocates
# 	alterations
# 	elliptical
# 	allocations
# 	heartbeats
# 	electrocardiogram
# 	dermatological
# Some words which never appear in Statistics papers:
# 	cognition
# 	marquardt
# 	constituency
# 	evidential
# 	switchboard
# 	authenticity
# 	capitalized
# 	functionalities
# 	contextualizing
# 	discontinuities
# 	radiologist
# 	ventricle
# 	imprecision
# 	smartphones
# 	propositional
# 	provability
# 	dempsters
# 	valuation
# 	coalitions
# 	valuations

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0752198782212926e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
